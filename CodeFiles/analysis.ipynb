# %% [markdown]
# # Greeting DS Montenegro!
# #

# %%
print(f"Hi there, {input('please input your name: ')}!")
# Out:
# Hi there, Ivan Bajceta!

# %% [markdown]
# - Question: How many records are in our sample below?

# %%
rows = [4,7,9,12]

len(rows)
# Out:
# 4

# %% [markdown]
# ## My observation
#
# The notebook contains executable code, explanatory text, and saved output

# %%
student_name = "Ivan Bajceta"
print(f"Hello, {student_name}!!!")
# Out:
# Hello, Ivan Bajceta!!!
